# %% [markdown]
# <a href="https://www.kaggle.com/code/mh0386/product-recommendation?scriptVersionId=138001996" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NearestNeighbors
from kagglehub import dataset_download

# %%
data = pd.read_csv(f'{dataset_download("karkavelrajaj/amazon-sales-dataset")}/amazon.csv')
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
data = data.drop(columns='product_name')
data = data.drop(columns='category')
data = data.drop(columns='discounted_price')
data = data.drop(columns='actual_price')
data = data.drop(columns='discount_percentage')
data = data.drop(columns='about_product')
data = data.drop(columns='user_name')
data = data.drop(columns='review_id')
data = data.drop(columns='review_title')
data = data.drop(columns='review_content')
data = data.drop(columns='img_link')
data = data.drop(columns='product_link')
data = data.drop(columns='rating_count')

# %%
data.head()
# Out:
#       product_id rating                                            user_id
# 0     B07JW9H4J1    4.2  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     B098NS6PVG    4.0  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     B096MSW6CT    3.9  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     B08HDJ86NZ    4.2  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     B08CF3B7N1    4.2  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...          ...    ...                                                ...
# 1460  B08L7J3T31      4  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  B01M6453MB    4.1  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  B009P2LIL4    3.6  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  B00J5DYCCA      4  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  B01486F4G6    4.3  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
# [1465 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# product_id    0
# rating        0
# user_id       0
# dtype: int64

# %% [markdown]
# # Check the distribution of the rating

# %%
plt.figure(figsize=(15, 8))
sns.countplot(data, x=data.rating.sort_values())
plt.show()

# %%
data = data.dropna()
data = data[data.rating != '|']

# %%
data.product_id = LabelEncoder().fit_transform(data.product_id)
data.user_id = LabelEncoder().fit_transform(data.user_id)

# %%
data
# Out:
#       product_id rating  user_id
# 0            346    4.2      623
# 1            847    4.0       88
# 2            818    3.9      848
# 3            643    4.2      254
# 4            588    4.2       17
# ...          ...    ...      ...
# 1460         672      4     1049
# 1461         201    4.1      425
# 1462          27    3.6      864
# 1463          61      4      300
# 1464         134    4.3      433
#
# [1464 rows x 3 columns]

# %% [markdown]
# # Splitting the dataset

# %%
trainSet, testSet = train_test_split(data, test_size=0.2, random_state=42)

# %%
trainSet
# Out:
#       product_id rating  user_id
# 1331         557    3.9     1188
# 724            3    4.3       47
# 254          436    3.6       94
# 1068         295    3.9     1017
# 1193         308    3.7      401
# ...          ...    ...      ...
# 1130         244    3.9      195
# 1295         496    3.9      385
# 860          789    3.9     1187
# 1460         672      4     1049
# 1126         105    4.1      561
#
# [1171 rows x 3 columns]

# %%
testSet
# Out:
#       product_id rating  user_id
# 1297         236    4.2     1170
# 175          947    3.7      615
# 275          955    3.3      220
# 548          680    4.3     1031
# 1000        1158    3.9       71
# ...          ...    ...      ...
# 1456        1263    3.2      391
# 481         1188    4.1      674
# 482          663    3.8      620
# 1303         744      4      832
# 1294         192    4.2      554
#
# [293 rows x 3 columns]

# %% [markdown]
# # Model

# %%
model = NearestNeighbors(metric='cosine', algorithm='brute')

# %%
model.fit(trainSet)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
distances, indices = model.kneighbors(trainSet)

# %%
distances
# Out:
# array([[0.00000000e+00, 4.30926042e-07, 8.95215081e-07, 1.32507681e-06,
#         1.93784945e-06],
#        [0.00000000e+00, 2.51480362e-03, 2.51480362e-03, 2.58177817e-03,
#         3.03003858e-03],
#        [0.00000000e+00, 7.11513843e-06, 9.00041208e-06, 1.27965496e-05,
#         1.41199245e-05],
#        ...,
#        [1.11022302e-16, 2.34822210e-06, 2.86820781e-06, 2.86820781e-06,
#         3.44382738e-06],
#        [0.00000000e+00, 2.22089835e-06, 6.16072585e-06, 7.03109809e-06,
#         1.03239811e-05],
#        [2.22044605e-16, 1.27852826e-06, 2.65020043e-06, 3.34687652e-06,
#         6.78999487e-06]], shape=(1171, 5))

# %%
indices
# Out:
# array([[   0,  155,  367,  780,  942],
#        [   1,  825,  443, 1154,  814],
#        [   2,  951, 1028,  471,   90],
#        ...,
#        [1168,  588,  129,  436,  933],
#        [1169, 1112,  392,  398,  739],
#        [1170,  664,  994, 1044,  580]], shape=(1171, 5))

# %%
plt.figure(figsize=(15, 8))
plt.scatter(x=range(0, len(indices)), y=indices[:, 0])
plt.scatter(x=range(0, len(indices)), y=indices[:, 1])
plt.scatter(x=range(0, len(indices)), y=indices[:, 2])
plt.scatter(x=range(0, len(indices)), y=indices[:, 3])
plt.scatter(x=range(0, len(indices)), y=indices[:, 4])
plt.show()

# %% [markdown]
# # Prediction

# %%
def predict(model, data, n_recommendations):
    distances, indices = model.kneighbors(data)
    for i in range(len(data)):
        print("Recommendations for product: ", data.iloc[i, 0])
        for j in range(1, n_recommendations + 1):
            try:
                print(f"{j}: {data.iloc[indices[i, j], 0]}, with distance of {distances[i, j]}")
            except:
                print("No more recommendations")
                continue
        print("\n")

# %%
predict(model, testSet, 5)
# Out:
# Recommendations for product:  236
# 1: 1022, with distance of 3.418142113020828e-06
# 2: 817, with distance of 9.860070224854134e-06
# 3: 810, with distance of 1.1542903411099203e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  947
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  955
# No more recommendations
# 2: 517, with distance of 8.964329120675352e-06
# 3: 395, with distance of 1.3281456370362044e-05
# 4: 150, with distance of 1.5060932341492972e-05
# No more recommendations
#
#
# Recommendations for product:  680
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 834, with distance of 1.3698672651774046e-06
# No more recommendations
#
#
# Recommendations for product:  1158
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  424
# No more recommendations
# 2: 834, with distance of 2.1046910348987424e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  880
# No more recommendations
# 2: 1298, with distance of 2.39777608257441e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  0
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  465
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  333
# No more recommendations
# 2: 626, with distance of 3.045338347396065e-05
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  763
# 1: 1275, with distance of 2.441474685754841e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  52
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  139
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  103
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  153
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 623, with distance of 1.0716449485581592e-05
# No more recommendations
#
#
# Recommendations for product:  222
# No more recommendations
# No more recommendations
# 3: 1188, with distance of 2.9175243266621464e-05
# 4: 71, with distance of 3.274051867063754e-05
# No more recommendations
#
#
# Recommendations for product:  311
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 571, with distance of 9.758989093056059e-06
# No more recommendations
#
#
# Recommendations for product:  1108
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1028, with distance of 1.456251692122379e-06
# No more recommendations
#
#
# Recommendations for product:  234
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1126
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 9, with distance of 3.512314092990465e-05
# No more recommendations
#
#
# Recommendations for product:  1268
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 899, with distance of 2.9475907171283566e-05
# No more recommendations
#
#
# Recommendations for product:  1040
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  593
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1108, with distance of 2.2552005261355923e-05
# No more recommendations
#
#
# Recommendations for product:  757
# No more recommendations
# 2: 457, with distance of 7.267980002834129e-06
# 3: 458, with distance of 1.1509894593531023e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  851
# No more recommendations
# No more recommendations
# 3: 1347, with distance of 1.1903989437511697e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  623
# 1: 923, with distance of 1.0936996552413092e-05
# No more recommendations
# 3: 28, with distance of 1.4635813115559948e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  683
# No more recommendations
# No more recommendations
# 3: 222, with distance of 1.8619144291132095e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  297
# No more recommendations
# No more recommendations
# 3: 1177, with distance of 4.540750064241372e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  235
# 1: 261, with distance of 1.535155192722293e-05
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  257
# No more recommendations
# 2: 114, with distance of 2.7670347920394356e-05
# No more recommendations
# 4: 264, with distance of 5.1082137025537655e-05
# No more recommendations
#
#
# Recommendations for product:  213
# No more recommendations
# No more recommendations
# 3: 1263, with distance of 2.2607442827227153e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  166
# 1: 68, with distance of 5.96309846645493e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  234
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1129
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  890
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1131
# No more recommendations
# 2: 394, with distance of 1.2250793751666933e-06
# 3: 1168, with distance of 1.7976065025404608e-06
# 4: 192, with distance of 5.01854320222872e-06
# No more recommendations
#
#
# Recommendations for product:  1258
# No more recommendations
# 2: 326, with distance of 4.418285959428836e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  622
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  638
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1298
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  859
# No more recommendations
# No more recommendations
# 3: 222, with distance of 1.636984890240889e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  872
# 1: 890, with distance of 1.2777791145168749e-06
# No more recommendations
# No more recommendations
# 4: 877, with distance of 4.944919890004229e-06
# No more recommendations
#
#
# Recommendations for product:  362
# No more recommendations
# 2: 923, with distance of 7.16076025308876e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  89
# No more recommendations
# 2: 354, with distance of 2.8928213868795183e-06
# 3: 967, with distance of 3.956883528832833e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  877
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 683, with distance of 4.966833919151092e-06
# No more recommendations
#
#
# Recommendations for product:  33
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  165
# No more recommendations
# No more recommendations
# 3: 457, with distance of 4.263607332244401e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1347
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1067
# No more recommendations
# No more recommendations
# 3: 391, with distance of 3.0335058942565496e-07
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1097
# 1: 842, with distance of 2.7916922338278027e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1259
# No more recommendations
# 2: 326, with distance of 4.391879096510287e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  316
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1046
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1302
# 1: 1053, with distance of 1.64720173190247e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1306
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  32
# 1: 235, with distance of 0.00011910721347496711
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  457
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  458
# 1: 655, with distance of 1.1980244876363955e-05
# 2: 1156, with distance of 1.2825601511390339e-05
# No more recommendations
# 4: 857, with distance of 1.67873673760921e-05
# No more recommendations
#
#
# Recommendations for product:  970
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  485
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  553
# No more recommendations
# 2: 28, with distance of 3.303289259015685e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1304
# 1: 360, with distance of 7.677376111514533e-07
# No more recommendations
# 3: 99, with distance of 6.978158486381503e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  226
# No more recommendations
# 2: 389, with distance of 2.286755026470466e-05
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  88
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  704
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1107
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1028, with distance of 2.2918009829897557e-06
# No more recommendations
#
#
# Recommendations for product:  399
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1041
# No more recommendations
# 2: 621, with distance of 4.885710017665801e-07
# 3: 465, with distance of 8.651189910002799e-07
# 4: 958, with distance of 4.111025011521718e-06
# No more recommendations
#
#
# Recommendations for product:  383
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  261
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1098, with distance of 3.461988958219919e-05
# No more recommendations
#
#
# Recommendations for product:  777
# No more recommendations
# 2: 523, with distance of 8.548894744331292e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  997
# No more recommendations
# 2: 524, with distance of 2.0936017830486264e-07
# No more recommendations
# 4: 1049, with distance of 5.578458590949076e-06
# No more recommendations
#
#
# Recommendations for product:  150
# No more recommendations
# 2: 961, with distance of 2.109866010457928e-05
# 3: 571, with distance of 2.307252350486344e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  138
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1193
# 1: 134, with distance of 4.672657183402151e-08
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  937
# 1: 522, with distance of 1.174168882789317e-06
# 2: 166, with distance of 1.174168882789317e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  769
# No more recommendations
# No more recommendations
# 3: 1217, with distance of 3.876373492195384e-07
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1208
# No more recommendations
# 2: 222, with distance of 3.4387111264022607e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  899
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 465, with distance of 8.527152615123157e-06
# No more recommendations
#
#
# Recommendations for product:  626
# No more recommendations
# 2: 32, with distance of 2.72760868347266e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1098
# No more recommendations
# 2: 1208, with distance of 1.004906420187801e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1156
# No more recommendations
# 2: 750, with distance of 9.427372734682749e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  395
# No more recommendations
# 2: 261, with distance of 6.625811820315519e-06
# 3: 68, with distance of 3.384977597853389e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1307
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1116
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  655
# 1: 1263, with distance of 3.6409263378667234e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  68
# No more recommendations
# No more recommendations
# 3: 769, with distance of 5.482788115585002e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  985
# No more recommendations
# 2: 304, with distance of 1.2847953090311393e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  587
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  984
# 1: 719, with distance of 1.111112027940564e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  509
# No more recommendations
# 2: 864, with distance of 2.154474033400078e-06
# No more recommendations
# 4: 909, with distance of 2.580657055051283e-06
# No more recommendations
#
#
# Recommendations for product:  963
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  475
# No more recommendations
# 2: 1343, with distance of 1.377561820326001e-05
# 3: 1090, with distance of 1.377561820326001e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  381
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1023
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  417
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  416
# No more recommendations
# No more recommendations
# 3: 187, with distance of 9.862708243213447e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1006
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  310
# No more recommendations
# 2: 1217, with distance of 2.948338847552634e-05
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  683
# No more recommendations
# No more recommendations
# 3: 222, with distance of 1.8619144291132095e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  864
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 906, with distance of 9.41053603242814e-06
# No more recommendations
#
#
# Recommendations for product:  857
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 821, with distance of 6.687742144517728e-06
# No more recommendations
#
#
# Recommendations for product:  243
# No more recommendations
# 2: 551, with distance of 9.869578539878354e-06
# No more recommendations
# 4: 236, with distance of 1.309281116057548e-05
# No more recommendations
#
#
# Recommendations for product:  682
# 1: 1100, with distance of 1.029777450511915e-05
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  578
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  394
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1158
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1209
# 1: 166, with distance of 6.386302372485275e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  523
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  571
# No more recommendations
# No more recommendations
# 3: 405, with distance of 4.912498600795345e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  300
# No more recommendations
# 2: 1156, with distance of 4.1636546762369164e-05
# 3: 655, with distance of 4.2178302633755216e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1093
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  558
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 923, with distance of 2.452357859306087e-05
# No more recommendations
#
#
# Recommendations for product:  634
# No more recommendations
# 2: 89, with distance of 3.35563632569702e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1243
# No more recommendations
# 2: 982, with distance of 1.4901428282421136e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  522
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  820
# No more recommendations
# No more recommendations
# 3: 222, with distance of 2.6163726438710455e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1348
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 707, with distance of 3.98989896666091e-06
# No more recommendations
#
#
# Recommendations for product:  906
# 1: 857, with distance of 9.593938421481596e-08
# 2: 1156, with distance of 1.0837041781730505e-06
# 3: 1041, with distance of 1.483192850759707e-06
# 4: 655, with distance of 9.735806344446374e-06
# No more recommendations
#
#
# Recommendations for product:  830
# 1: 705, with distance of 9.708444262956917e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  148
# 1: 1263, with distance of 4.400128302139983e-05
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  132
# No more recommendations
# 2: 704, with distance of 0.000269532944945472
# No more recommendations
# 4: 593, with distance of 0.00028838392642960287
# No more recommendations
#
#
# Recommendations for product:  689
# 1: 890, with distance of 6.360790160142571e-07
# No more recommendations
# No more recommendations
# 4: 1302, with distance of 3.0492070324239506e-06
# No more recommendations
#
#
# Recommendations for product:  982
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  30
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  822
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  99
# No more recommendations
# 2: 1046, with distance of 2.0505584520158493e-05
# No more recommendations
# 4: 1093, with distance of 2.732898787949356e-05
# No more recommendations
#
#
# Recommendations for product:  839
# No more recommendations
# 2: 1035, with distance of 5.025286490267789e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1082
# 1: 958, with distance of 1.4503185217229486e-06
# No more recommendations
# 3: 621, with distance of 2.408481909910165e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  834
# 1: 234, with distance of 6.944433955657914e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1076
# No more recommendations
# 2: 978, with distance of 1.612455021837711e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  967
# No more recommendations
# 2: 192, with distance of 2.3442087980773962e-06
# 3: 394, with distance of 3.467027558379243e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1237
# 1: 634, with distance of 3.091311923553164e-06
# No more recommendations
# 3: 522, with distance of 4.806741417673344e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  922
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  172
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  408
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  522
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1043
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1181
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  170
# No more recommendations
# 2: 1093, with distance of 4.946611976364146e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  550
# 1: 174, with distance of 4.203524215040666e-06
# No more recommendations
# 3: 475, with distance of 5.992754259942501e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1034
# No more recommendations
# 2: 205, with distance of 2.630019304561415e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  354
# No more recommendations
# 2: 578, with distance of 3.858326629457842e-05
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  897
# No more recommendations
# 2: 668, with distance of 1.578268319413212e-05
# 3: 886, with distance of 1.6193229085303962e-05
# 4: 898, with distance of 2.5408445274766045e-05
# No more recommendations
#
#
# Recommendations for product:  232
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1108, with distance of 3.2945020621011345e-05
# No more recommendations
#
#
# Recommendations for product:  8
# No more recommendations
# No more recommendations
# 3: 769, with distance of 0.009697742380775254
# 4: 558, with distance of 0.009863630883634955
# No more recommendations
#
#
# Recommendations for product:  968
# 1: 1168, with distance of 2.8698809340088616e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  517
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 148, with distance of 8.931630648079114e-06
# No more recommendations
#
#
# Recommendations for product:  842
# 1: 982, with distance of 4.026873324347591e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  730
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  432
# 1: 1158, with distance of 2.967680829413233e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  978
# 1: 170, with distance of 1.4446445240068329e-07
# No more recommendations
# 3: 1246, with distance of 2.942962690211104e-07
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  852
# 1: 405, with distance of 6.164310804024353e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  339
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1095
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  551
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  966
# 1: 634, with distance of 5.889244379275738e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1100
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1322
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  787
# 1: 522, with distance of 2.4891149503769583e-06
# 2: 166, with distance of 2.4891149503769583e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  529
# 1: 777, with distance of 8.203071258927608e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  973
# 1: 234, with distance of 5.55227201448627e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  624
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 522, with distance of 1.0029390807297922e-05
# No more recommendations
#
#
# Recommendations for product:  1165
# No more recommendations
# 2: 1208, with distance of 3.802432160249225e-07
# No more recommendations
# 4: 450, with distance of 4.662331962612676e-06
# No more recommendations
#
#
# Recommendations for product:  290
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  707
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  592
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 311, with distance of 3.0090073968480624e-05
# No more recommendations
#
#
# Recommendations for product:  882
# No more recommendations
# 2: 43, with distance of 1.4787382174308306e-06
# 3: 32, with distance of 2.0580819691806695e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1271
# No more recommendations
# 2: 326, with distance of 6.675989456250697e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  611
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1098, with distance of 1.7358136801814972e-05
# No more recommendations
#
#
# Recommendations for product:  620
# No more recommendations
# No more recommendations
# 3: 923, with distance of 1.4425860190514506e-05
# 4: 28, with distance of 1.8925271542569178e-05
# No more recommendations
#
#
# Recommendations for product:  1308
# No more recommendations
# No more recommendations
# 3: 1243, with distance of 9.324456784476354e-07
# 4: 968, with distance of 4.170917680679231e-06
# No more recommendations
#
#
# Recommendations for product:  303
# No more recommendations
# 2: 1168, with distance of 2.502705395501792e-05
# 3: 394, with distance of 2.59540205029829e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1168
# No more recommendations
# 2: 1107, with distance of 1.7116449911869225e-06
# 3: 962, with distance of 4.883114848919234e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  988
# 1: 719, with distance of 1.2113389565859833e-06
# 2: 304, with distance of 2.049803152881502e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  326
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1177
# No more recommendations
# No more recommendations
# 3: 9, with distance of 3.553645267095895e-05
# 4: 160, with distance of 4.0309563961948847e-05
# No more recommendations
#
#
# Recommendations for product:  1088
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1035
# 1: 234, with distance of 6.38163588639884e-08
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  568
# No more recommendations
# 2: 763, with distance of 4.645146549187018e-06
# No more recommendations
# 4: 906, with distance of 5.996227401050547e-06
# No more recommendations
#
#
# Recommendations for product:  360
# No more recommendations
# No more recommendations
# 3: 966, with distance of 2.019016274878993e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1239
# 1: 857, with distance of 4.495340334420561e-07
# No more recommendations
# 3: 1156, with distance of 9.7308763158388e-07
# 4: 655, with distance of 7.448006846155764e-06
# No more recommendations
#
#
# Recommendations for product:  923
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  397
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  846
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  494
# 1: 457, with distance of 4.465214434756781e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  289
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  410
# 1: 1156, with distance of 1.211565296899142e-05
# No more recommendations
# 3: 857, with distance of 1.3264898208742437e-05
# 4: 1041, with distance of 1.809715838707593e-05
# No more recommendations
#
#
# Recommendations for product:  1049
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1117
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  173
# 1: 882, with distance of 1.9650478061072896e-05
# No more recommendations
# No more recommendations
# 4: 604, with distance of 0.00010222537132908993
# No more recommendations
#
#
# Recommendations for product:  435
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  472
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  28
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  962
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1126, with distance of 1.0046912065075908e-05
# No more recommendations
#
#
# Recommendations for product:  1053
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 399, with distance of 1.0416819702818714e-05
# No more recommendations
#
#
# Recommendations for product:  65
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  829
# 1: 0, with distance of 2.499142353062922e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  543
# 1: 551, with distance of 1.597763827354548e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  524
# No more recommendations
# 2: 1237, with distance of 2.0608285493883827e-05
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  752
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  589
# 1: 834, with distance of 1.1102230246251565e-16
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1218
# 1: 170, with distance of 1.4722382948306745e-06
# 2: 1246, with distance of 1.749467409495331e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1328
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1116, with distance of 1.456251692122379e-06
# No more recommendations
#
#
# Recommendations for product:  92
# No more recommendations
# 2: 1056, with distance of 4.3654309832552585e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  13
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  9
# No more recommendations
# No more recommendations
# 3: 165, with distance of 0.00011007728602641098
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  71
# No more recommendations
# No more recommendations
# 3: 123, with distance of 5.780261347454463e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  447
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  705
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 89, with distance of 4.66413035327129e-06
# No more recommendations
#
#
# Recommendations for product:  405
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  349
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  816
# No more recommendations
# No more recommendations
# 3: 205, with distance of 1.832686624014812e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  519
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1022
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  911
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1262
# No more recommendations
# 2: 475, with distance of 2.066761443009213e-05
# 3: 683, with distance of 2.124546201132116e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  635
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1028
# No more recommendations
# 2: 982, with distance of 3.4860575093276225e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  594
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  984
# 1: 719, with distance of 1.111112027940564e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  252
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  283
# No more recommendations
# No more recommendations
# 3: 663, with distance of 3.727383190721412e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  160
# 1: 839, with distance of 2.2849958106752055e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  205
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 611, with distance of 9.597243696202185e-05
# No more recommendations
#
#
# Recommendations for product:  1056
# 1: 1035, with distance of 4.2298901614667983e-07
# No more recommendations
# 3: 1347, with distance of 2.3866847500553234e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  538
# No more recommendations
# 2: 213, with distance of 2.8731118234537334e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1092
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 730, with distance of 1.0164454899652675e-05
# No more recommendations
#
#
# Recommendations for product:  1090
# No more recommendations
# 2: 663, with distance of 1.0838735615692485e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  391
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  849
# No more recommendations
# 2: 360, with distance of 5.890980928291434e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  961
# 1: 234, with distance of 8.921121034455304e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1275
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  958
# No more recommendations
# 2: 1181, with distance of 6.257977963608496e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  43
# No more recommendations
# No more recommendations
# 3: 882, with distance of 0.0020601700577396187
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1343
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1308, with distance of 2.89163752460464e-05
# No more recommendations
#
#
# Recommendations for product:  434
# 1: 1165, with distance of 8.61288663167592e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  898
# 1: 0, with distance of 8.455001673901563e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  450
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 524, with distance of 1.709046782094603e-05
# No more recommendations
#
#
# Recommendations for product:  841
# No more recommendations
# 2: 663, with distance of 1.0692056165995112e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  686
# No more recommendations
# No more recommendations
# 3: 683, with distance of 5.66262237799986e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  604
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 148, with distance of 1.4272852671415315e-05
# No more recommendations
#
#
# Recommendations for product:  47
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1174
# 1: 0, with distance of 7.013087777174576e-08
# No more recommendations
# No more recommendations
# 4: 138, with distance of 1.9551473399159747e-06
# No more recommendations
#
#
# Recommendations for product:  174
# 1: 882, with distance of 1.266635633001556e-05
# No more recommendations
# No more recommendations
# 4: 604, with distance of 0.0001081344023179387
# No more recommendations
#
#
# Recommendations for product:  277
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  621
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  810
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  821
# 1: 682, with distance of 1.3739907932519557e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  123
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  719
# No more recommendations
# 2: 1082, with distance of 4.36421048144453e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1215
# No more recommendations
# No more recommendations
# 3: 192, with distance of 2.379301762056585e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1187
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1195
# 1: 134, with distance of 8.740730894629678e-08
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  549
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  389
# 1: 28, with distance of 1.7054651735293191e-07
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  66
# No more recommendations
# 2: 290, with distance of 0.000367086223506341
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  747
# No more recommendations
# 2: 1193, with distance of 2.8535121905370886e-06
# No more recommendations
# 4: 984, with distance of 3.0334937385356753e-06
# No more recommendations
#
#
# Recommendations for product:  668
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 65, with distance of 4.198663269949776e-06
# No more recommendations
#
#
# Recommendations for product:  1246
# No more recommendations
# No more recommendations
# 3: 205, with distance of 4.46673306564449e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  492
# 1: 522, with distance of 6.7495516564708424e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  909
# No more recommendations
# 2: 857, with distance of 2.874077373871131e-07
# 3: 1041, with distance of 6.376141792330259e-07
# 4: 655, with distance of 5.4766856927290775e-06
# No more recommendations
#
#
# Recommendations for product:  134
# No more recommendations
# No more recommendations
# 3: 1117, with distance of 1.567158485649145e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  224
# No more recommendations
# 2: 289, with distance of 3.436271211576525e-06
# 3: 810, with distance of 4.661823418183886e-06
# 4: 1022, with distance of 9.31365929923711e-06
# No more recommendations
#
#
# Recommendations for product:  77
# 1: 937, with distance of 1.3956778035506545e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  428
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1328, with distance of 3.3698278882887678e-06
# No more recommendations
#
#
# Recommendations for product:  614
# 1: 1006, with distance of 2.220446049250313e-16
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  696
# No more recommendations
# 2: 834, with distance of 2.470024659029235e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  266
# 1: 986, with distance of 2.637057029963863e-06
# 2: 123, with distance of 3.2893271859624207e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  986
# 1: 719, with distance of 1.4929917180328545e-07
# 2: 304, with distance of 5.134285097074809e-07
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  304
# 1: 1092, with distance of 2.4412412903407343e-06
# 2: 852, with distance of 2.9637484491029653e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  45
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  825
# 1: 234, with distance of 7.804976967729083e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  500
# No more recommendations
# 2: 213, with distance of 4.838963418518638e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  748
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1217
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  499
# 1: 88, with distance of 1.0078922645817556e-05
# No more recommendations
# No more recommendations
# 4: 236, with distance of 2.4768831221155807e-05
# No more recommendations
#
#
# Recommendations for product:  817
# No more recommendations
# No more recommendations
# No more recommendations
# 4: 1298, with distance of 8.254238130445124e-06
# No more recommendations
#
#
# Recommendations for product:  114
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  231
# No more recommendations
# 2: 1022, with distance of 1.982392841426428e-05
# 3: 817, with distance of 2.3389583914235068e-05
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1293
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  264
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  199
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  187
# No more recommendations
# 2: 1304, with distance of 2.711241339992121e-06
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  348
# No more recommendations
# No more recommendations
# 3: 1046, with distance of 8.083044311879561e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  608
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  886
# No more recommendations
# 2: 150, with distance of 9.636307279459189e-06
# 3: 395, with distance of 1.014343084304592e-05
# 4: 1053, with distance of 1.3734555287081562e-05
# No more recommendations
#
#
# Recommendations for product:  750
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1263
# 1: 1049, with distance of 1.1193954547739082e-06
# No more recommendations
# 3: 1268, with distance of 3.3609281840929484e-06
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  1188
# 1: 970, with distance of 2.603790207889034e-07
# No more recommendations
# 3: 494, with distance of 8.471738206505819e-07
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  663
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  744
# 1: 303, with distance of 2.566359613154212e-06
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
#
#
# Recommendations for product:  192
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
# No more recommendations
